# %% [markdown]
# ### Work in progress
# Вариант с более тщательным отбором признаков для преобразования в унитарный код.

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
import chime

# %%
# %load_ext chime

# %%
class Concatenator:
    # Adding calendar and review data
    def __init__(self):
        self.calendar = pd.read_csv('calendar_availability.csv',
                                   index_col='listing_id')
        self.reviews = pd.read_csv('reviews_stat.csv',
                                  index_col='listing_id')
        
    def fit(self, df, y=None):
        result = df.copy().join([self.calendar, self.reviews], how='left')
        result.drop(columns='host_id', inplace=True)
        return result
    
    def transform(self, df, y=None):
        result = df.copy().join([self.calendar, self.reviews], how='left')
        result.drop(columns='host_id', inplace=True)
        return result

# %%
class PercentConvert:
    #Convert column with the percent sign
    def __init__(self):
        pass
    
    def fit(self, df, y=None):
        return self
    
    def transform(self, df, y=None):
        result = df.copy()
        result['host_response_rate'] = result['host_response_rate']\
            .str.replace(r'\D+', '', regex=True)\
            .astype('float')
        return result

# %%
class FeatureTransform:
    # Transform features depending on type
    def __init__(self, n):
        self.n = n
        self.uncorrelated_features = ['latitude', 'longitude',
                                      'available', 'comments',
                                      'canceled', 'notice',
                                      'host_response_rate']
        self.correlated_features = ['accommodates', 'bathrooms', 'beds','guests_included',
                                    'security_deposit','bedrooms','minimum_nights',
                                    'extra_people','square_feet','cleaning_fee']
        self.features = self.correlated_features + ['latitude', 'longitude']

    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        df = X.copy()

        # Convert datetimes into numbers for further use as a numeric variable
        # This will apply to the host_since column
        date_features = df.select_dtypes(include='datetime').columns
        df[date_features] = df[date_features].astype(np.int64)
        
        # Identify and scale numeric features
        numeric_features = df.select_dtypes(include='number').columns
        df[numeric_features] = pd.DataFrame(
            StandardScaler().fit_transform(df[numeric_features]),
            columns=numeric_features,
            index=df.index
        )
        
        # Identify categorical features with more than n unique values
        # and convert each into a binary feature: data provided or not
        cat_features = df.select_dtypes(include=['object', 'bool']).nunique()
        long = cat_features[cat_features > self.n].index
        df[long] = df[long].isna()
        
        # Filling NaNs in uncorrelated features
        df[self.uncorrelated_features] = df[self.uncorrelated_features].fillna(0, axis=0)

        # Fill NaN in correlated features 
        # and one hot encode categorical features with unique values <= n
        short = cat_features[cat_features <= self.n].index
        
        # Добавил долготу и широту, чтобы не пропадали колонки
        impute_encode = ColumnTransformer(
            transformers = [
                ('corr', KNNImputer(n_neighbors=50), self.features),
                ('get_dummies', OneHotEncoder(sparse=False, drop=None, handle_unknown='ignore'), short)
            ],
            remainder='passthrough',
            n_jobs=-1
        )
         
        pipe_impute_encode = Pipeline([('impute_encode', impute_encode)])
        result = pipe_impute_encode.fit_transform(df)
        return result

# %%
train = pd.read_csv('train.csv',
                    index_col='id',
                    true_values=['t'],
                    false_values=['f'],
                    na_values='none',
                    parse_dates=['host_since'],
                   low_memory=False)
train
# Out:
#                                                        name  \
# id
# 20145777                         Double in a friendly house
# 22630537             London flat with great transport links
# 27355619  Studio Apartments, 5 mins to Kings Cross Station!
# 21011236   Big, Beautiful, Sunny, West Kensington TWIN Room
# 24754494                 Dashing 1BR in Bayswater by Sonder
# ...                                                     ...
# 18151315     Sunny studio with private kitchen and bathroom
# 28105053    A comfy double room in modern flat ★ Haggerston
# 26342100          Goldsborough House - Apartment London SW8
# 13833612                Modern and Luxurious 1 Bedroom Flat
# 19640194            SunnyBay - Very Cosy and beautiful home
#
#                                                     summary  \
# id
# 20145777  A  double bedroom  in a cozy and modern apartm...
# 22630537  Light, airy and modern one bedroom flat 2 mins...
# 27355619  Based in high quality student accommodation, o...
# 21011236  Big Beautiful, airy, West Kensington TWIN room...
# 24754494  At this Sonder, you'll love the chic decor, st...
# ...                                                     ...
# 18151315  Quiet, sunny studio flat just minutes from the...
# 28105053                   It's a double room for 2 guests.
# 26342100  Spacious three bedroom flat, fantastic locatio...
# 13833612  You’ll love my place because of the ambiance, ...
# 19640194  A fantastic two bedroom terraced house situate...
#
#                                                       space  \
# id
# 20145777                                                NaN
# 22630537                                                NaN
# 27355619  What To Expect: * 16/17m2 Studio with modern f...
# 21011236  This is a pretty terraced house in a great are...
# 24754494  Every booking is instantly confirmed. Every ca...
# ...                                                     ...
# 18151315  A small and very cosy flat with all necessary ...
# 28105053                                                NaN
# 26342100                                                NaN
# 13833612  This is a beautiful and comfortable one bedroo...
# 19640194                                                NaN
#
#                                                 description  \
# id
# 20145777  A  double bedroom  in a cozy and modern apartm...
# 22630537  Light, airy and modern one bedroom flat 2 mins...
# 27355619  Based in high quality student accommodation, o...
# 21011236  Big Beautiful, airy, West Kensington TWIN room...
# 24754494  At this Sonder, you'll love the chic decor, st...
# ...                                                     ...
# 18151315  Quiet, sunny studio flat just minutes from the...
# 28105053  It's a double room for 2 guests. I will be at ...
# 26342100  Spacious three bedroom flat, fantastic locatio...
# 13833612  You’ll love my place because of the ambiance, ...
# 19640194  A fantastic two bedroom terraced house situate...
#
#          experiences_offered  \
# id
# 20145777                 NaN
# 22630537                 NaN
# 27355619                 NaN
# 21011236                 NaN
# 24754494                 NaN
# ...                      ...
# 18151315                 NaN
# 28105053                 NaN
# 26342100                 NaN
# 13833612                 NaN
# 19640194                 NaN
#
#                                       neighborhood_overview  \
# id
# 20145777                                                NaN
# 22630537                                                NaN
# 27355619  As one of Central London’s most vibrant and ne...
# 21011236  We’re in a fantastic location - close to many ...
# 24754494  Your Sonder is in a beautiful dwelling, conver...
# ...                                                     ...
# 18151315  Crystal Palace is a vibrant bohemian oasis sur...
# 28105053                                                NaN
# 26342100                                                NaN
# 13833612  The are is central and well connected. For pub...
# 19640194                                                NaN
#
#                                                       notes  \
# id
# 20145777                                                NaN
# 22630537                                                NaN
# 27355619  • Do you have free WiFi? Yes we have super fas...
# 21011236  We lay on a good breakfast that guests serve t...
# 24754494  This Sonder does not have air conditioning, bu...
# ...                                                     ...
# 18151315                                                NaN
# 28105053                                                NaN
# 26342100                                                NaN
# 13833612  I expect people to treat the flat with respect...
# 19640194                                                NaN
#
#                                                     transit  \
# id
# 20145777                                                NaN
# 22630537                                                NaN
# 27355619  You will be in an incredible position for gett...
# 21011236                                                NaN
# 24754494  Your Sonder is located at the end of a cul-de-...
# ...                                                     ...
# 18151315  2 mins to Gipsy Hill Rail,  direct links to Vi...
# 28105053  There is Haggerston overground station only 3 ...
# 26342100                                                NaN
# 13833612  Easy access to public transport (DLR, Overgrou...
# 19640194                                                NaN
#
#                                                      access  \
# id
# 20145777                                                NaN
# 22630537                                                NaN
# 27355619  You will enjoy your own studio, with a private...
# 21011236  The room is exclusively yours while you're her...
# 24754494                                                NaN
# ...                                                     ...
# 18151315  You have shared access through main front door...
# 28105053                                                NaN
# 26342100                                                NaN
# 13833612  Full access to all spaces. The flat is all you...
# 19640194                                                NaN
#
#                                                 interaction  ... square_feet  \
# id                                                           ...
# 20145777                                                NaN  ...         NaN
# 22630537                                                NaN  ...         NaN
# 27355619  Our reception can help you out with anything y...  ...         NaN
# 21011236  I'm Matthew and I live here with my son Alex. ...  ...         NaN
# 24754494  Our concierge is available by phone, email, or...  ...         NaN
# ...                                                     ...  ...         ...
# 18151315  I have an apartment manager who lives close by...  ...         NaN
# 28105053  I will be at the Airbnb to greet you and check...  ...         NaN
# 26342100                                                NaN  ...         NaN
# 13833612  I am available to help via email / phone and c...  ...         NaN
# 19640194                                                NaN  ...         NaN
#
#           security_deposit cleaning_fee guests_included extra_people  \
# id
# 20145777               NaN          NaN               1          0.0
# 22630537               NaN         25.0               2         20.0
# 27355619              80.0         45.0               1          0.0
# 21011236               NaN         12.0               1         11.0
# 24754494             300.0         63.0               2          5.0
# ...                    ...          ...             ...          ...
# 18151315               NaN         25.0               1          0.0
# 28105053               0.0         10.0               1         10.0
# 26342100               NaN          NaN               1          0.0
# 13833612              80.0         25.0               1          0.0
# 19640194               NaN          NaN               1          0.0
#
#          minimum_nights          cancellation_policy  \
# id
# 20145777              1                     flexible
# 22630537              1                     moderate
# 27355619              3                     flexible
# 21011236              1                     moderate
# 24754494              2  strict_14_with_grace_period
# ...                 ...                          ...
# 18151315              2                     moderate
# 28105053              2  strict_14_with_grace_period
# 26342100              1                     flexible
# 13833612              4                     moderate
# 19640194              6                     flexible
#
#          require_guest_profile_picture require_guest_phone_verification  price
# id
# 20145777                         False                            False   90.0
# 22630537                         False                            False   75.0
# 27355619                         False                            False   89.0
# 21011236                         False                            False   60.0
# 24754494                         False                            False  169.0
# ...                                ...                              ...    ...
# 18151315                         False                            False   65.0
# 28105053                         False                            False   31.0
# 26342100                         False                            False  150.0
# 13833612                         False                            False  105.0
# 19640194                         False                            False  149.0
#
# [36270 rows x 42 columns]

# %%
X = train.drop(columns='price')
y = train.price

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, 
                                                  test_size=0.2,
                                                  random_state=8,
                                                 shuffle=True)

# %%
X_val.shape
# Out:
# (7254, 41)

# %% [markdown]
# ### Пропущенные значения

# %% [markdown]
# Для признаков, между которыми есть корреляция, использовал KNNImputer.
# У независимых друг от друга признаков использовал среднее значение, равное 0, т.к. признаки стандартизованы. Сделал это зараннее в классе FeatureTransform, чтобы дать KNNImputer за что "зацепиться": KNN Imputer выкидывает колонки, если не может подобрать соседей, поэтому включил в список признаков долготу и широту (у них пропущенные значения уже заполнены). (Проблема с потерянными колонками возникает при преобразовании малых выборок на этапе тестирования.)

# %% [markdown]
# correlated_features = ['accommodates', 'bathrooms', 'beds','guests_included','security_deposit',
#                        'bedrooms','minimum_nights','extra_people','square_feet','cleaning_fee']
# features = correlated_features + ['latitude', 'longitude']
#
# # Добавил долготу и широту, чтобы не пропадали колонки
# impute_encode = ColumnTransformer(
#     transformers = [
#         ('corr', KNNImputer(n_neighbors=50), features)
#     ],
#     remainder=OneHotEncoder(sparse=False, handle_unknown='ignore'),
#     n_jobs=-1
# )

# %% [markdown]
# correlated_features = ['accommodates', 'bathrooms', 'beds','guests_included','security_deposit',
#                        'bedrooms','minimum_nights','extra_people','square_feet','cleaning_fee']
# features = correlated_features + ['latitude', 'longitude']
#
# # Добавил долготу и широту, чтобы не пропадали колонки
# impute_encode = ColumnTransformer(
#     transformers = [
#         ('get_dummies', OneHotEncoder(sparse=False, handle_unknown='ignore'), cols)
#     ],
#
#     n_jobs=-1
# )

# %%
preprocess_steps = [('percent_convert', PercentConvert()),
                   ('join_data', Concatenator()),
                   ('transform', FeatureTransform(10))
                   ]
pipe_preprocess = Pipeline(preprocess_steps, verbose=True)

# %%
# %%time
# %%chime
X_train_transf = pipe_preprocess.fit_transform(X_train); X_train_transf
# Out:
# [Pipeline] ... (step 1 of 3) Processing percent_convert, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing join_data, total=   0.3s
# [Pipeline] ......... (step 3 of 3) Processing transform, total= 1.1min
# CPU times: total: 938 ms
# Wall time: 1min 4s

# %%
X_train_transf.shape
# Out:
# (29016, 70)

# %%
X_train_transf
# Out:
# array([[0.3846094631742136, 1.1390736547809788, 0.1793403520770507, ...,
#         -0.20051885555717758, -0.3364019047375185, 0.0],
#        [0.3846094631742136, -0.47794391425224697, 0.1793403520770507,
#         ..., -0.10061329694835491, 0.13439225549506964,
#         -0.3359467322925266],
#        [0.8842883466461836, 1.1390736547809788, 0.9930838600295439, ...,
#         -0.050660517643943574, -0.3364019047375185, 0.0],
#        ...,
#        [-0.6147483037697266, -0.47794391425224697, -0.6344031558754425,
#         ..., -0.3503771934704116, -0.3364019047375185, 0.0],
#        [0.3846094631742136, -0.47794391425224697, 0.1793403520770507,
#         ..., 2.7466951234030907, -0.3364019047375185, 0.0],
#        [0.3846094631742136, -0.47794391425224697, 0.1793403520770507,
#         ..., -0.4003299727748229, -0.3364019047375185, 0.0]], dtype=object)

# %%
# %%time
# %%chime
X_val_transf = pipe_preprocess.transform(X_val); X_val_transf
# Out:
# CPU times: total: 359 ms
# Wall time: 4.6 s

# %%
X_val_transf.shape
# Out:
# (7254, 67)

# %% [markdown]
# # Выбор модели

# %% [markdown]
# ## Предсказание по средней цене

# %%
y_val.describe()
# Out:
# count    7254.000000
# mean      115.931624
# std       175.953193
# min         0.000000
# 25%        45.000000
# 50%        85.000000
# 75%       135.000000
# max      7716.000000
# Name: price, dtype: float64

# %%
(y_val - y_val.mean()).abs().mean()
# Out:
# 74.18344137864436

# %% [markdown]
# ## Линейная регрессия

# %%
params = {'alpha': np.arange(0.2, 1.0, 0.1).tolist() + np.arange(1.0, 10, 1).tolist(),
         'l1_ratio': [0.1, 0.5, 0.8, 0.95, 0.99, 1]}

# %%
regressor = ElasticNet(max_iter=1000,
                       random_state=8)
lin_reg = GridSearchCV(estimator = regressor,
                      param_grid = params,
                      scoring='neg_mean_absolute_error',
                      n_jobs=-1, 
                      refit=True,
                      cv=5)

# %%
# %%time
# %%chime
lin_reg.fit(X_train_transf, y_train)
# Out:
# CPU times: total: 1min 18s
# Wall time: 1min 48s

# %%
lin_reg.best_score_
# Out:
# -48.952944071094954

# %%
lin_reg.best_params_
# Out:
# {'alpha': 2.0, 'l1_ratio': 0.95}

# %%
best_regressor = lin_reg.best_estimator_

# %%
y_pred_1 = best_regressor.predict(X_val_transf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 y_pred_1 = best_regressor.predict(X_val_transf)
#
# File E:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File E:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1127, in ElasticNet._decision_function(self, X)
#    1125     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#    1126 else:
# -> 1127     return super()._decision_function(X)
#
# File E:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File E:\Programs\Anaconda\lib\site-packages\sklearn\base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File E:\Programs\Anaconda\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 67 features, but ElasticNet is expecting 70 features as input.

# %%
tmp = OneHotEncoder(sparse=False, drop=None, handle_unknown='ignore').fit(X_train)

# %%
tmp2 = tmp.transform(X_val)

# %%
tmp2.shape
# Out:
# (7254, 306255)

# %%
uncorrelated_features = ['latitude', 'longitude']
                              
correlated_features = ['accommodates', 'bathrooms', 'beds','guests_included',
                            'security_deposit','bedrooms','minimum_nights',
                            'extra_people','square_feet','cleaning_fee']
features = correlated_features + ['latitude', 'longitude']
cat_features = X_train.select_dtypes(include=['object', 'bool']).nunique()
long = cat_features[cat_features > 10].index
X_train[long] = X_train[long].isna()

# Filling NaNs in uncorrelated features
X_train[uncorrelated_features] = X_train[uncorrelated_features].fillna(0, axis=0)

# Fill NaN in correlated features 
# and one hot encode categorical features with unique values <= n
short = cat_features[cat_features <= 10].index

# Добавил долготу и широту, чтобы не пропадали колонки
impute_encode = ColumnTransformer(
    transformers = [
        ('corr', KNNImputer(n_neighbors=50), features),
        ('get_dummies', OneHotEncoder(sparse=False, drop=None, handle_unknown='ignore'), short)
    ],
    remainder='passthrough',
    n_jobs=-1
)

# %%
pipe_impute_encode = Pipeline([('impute_encode', impute_encode)])
df1 = pipe_impute_encode.fit_transform(X_train)

# %%
df1.shape
# Out:
# (29016, 80)

# %%
# %%chime
# df2 = pipe_impute_encode.transform(X_val)

# %%
df2.shape
# Out:
# (7254, 80)

# %%
f = ['latitude', 'longitude',
                                      'available', 'comments',
                                      'canceled', 'notice'
                                      ]

# %%
X_train
# Out:
#            name  summary  space  description experiences_offered  \
# id
# 25761038  False    False  False        False                 NaN
# 18440734  False    False  False        False                 NaN
# 15457138  False    False   True        False                 NaN
# 17555101  False    False  False        False                 NaN
# 28234588  False    False  False        False                 NaN
# ...         ...      ...    ...          ...                 ...
# 13749393  False    False  False        False                 NaN
# 27457076  False    False  False        False                 NaN
# 25771345  False    False  False        False                 NaN
# 19995526  False    False  False        False                 NaN
# 24589287  False    False   True        False                 NaN
#
#           neighborhood_overview  notes  transit  access  interaction  ...  \
# id                                                                    ...
# 25761038                  False  False    False   False        False  ...
# 18440734                   True   True     True    True         True  ...
# 15457138                  False   True    False    True        False  ...
# 17555101                   True   True    False    True         True  ...
# 28234588                   True   True     True    True         True  ...
# ...                         ...    ...      ...     ...          ...  ...
# 13749393                  False   True    False   False        False  ...
# 27457076                  False   True    False   False        False  ...
# 25771345                   True   True     True    True         True  ...
# 19995526                  False  False    False   False        False  ...
# 24589287                   True   True     True    True         True  ...
#
#           amenities  square_feet security_deposit  cleaning_fee  \
# id
# 25761038      False          NaN              0.0          60.0
# 18440734      False          NaN            300.0          55.0
# 15457138      False          NaN            350.0           0.0
# 17555101      False          NaN              NaN           NaN
# 28234588      False          NaN              0.0           5.0
# ...             ...          ...              ...           ...
# 13749393      False          NaN            500.0          30.0
# 27457076      False          NaN              NaN           NaN
# 25771345      False          NaN              NaN           NaN
# 19995526      False          NaN              0.0          17.0
# 24589287      False          NaN            100.0          20.0
#
#          guests_included  extra_people minimum_nights  \
# id
# 25761038               2          15.0              2
# 18440734               1           0.0              2
# 15457138               1           0.0              2
# 17555101               1           0.0              2
# 28234588               1          10.0              2
# ...                  ...           ...            ...
# 13749393               1          15.0              4
# 27457076               1           0.0              4
# 25771345               1           0.0              1
# 19995526               1           0.0              2
# 24589287               1           0.0              3
#
#                   cancellation_policy require_guest_profile_picture  \
# id
# 25761038  strict_14_with_grace_period                         False
# 18440734  strict_14_with_grace_period                         False
# 15457138  strict_14_with_grace_period                         False
# 17555101  strict_14_with_grace_period                         False
# 28234588                     flexible                         False
# ...                               ...                           ...
# 13749393                     moderate                         False
# 27457076  strict_14_with_grace_period                         False
# 25771345                     flexible                         False
# 19995526  strict_14_with_grace_period                         False
# 24589287                     flexible                         False
#
#           require_guest_phone_verification
# id
# 25761038                             False
# 18440734                             False
# 15457138                             False
# 17555101                             False
# 28234588                             False
# ...                                    ...
# 13749393                             False
# 27457076                             False
# 25771345                             False
# 19995526                             False
# 24589287                             False
#
# [29016 rows x 41 columns]

# %%
X_train['experiences_offered'] = X_train['experiences_offered'].fillna(0, axis=0)
X_train
# Out:
#            name  summary  space  description experiences_offered  \
# id
# 25761038  False    False  False        False                   0
# 18440734  False    False  False        False                   0
# 15457138  False    False   True        False                   0
# 17555101  False    False  False        False                   0
# 28234588  False    False  False        False                   0
# ...         ...      ...    ...          ...                 ...
# 13749393  False    False  False        False                   0
# 27457076  False    False  False        False                   0
# 25771345  False    False  False        False                   0
# 19995526  False    False  False        False                   0
# 24589287  False    False   True        False                   0
#
#           neighborhood_overview  notes  transit  access  interaction  ...  \
# id                                                                    ...
# 25761038                  False  False    False   False        False  ...
# 18440734                   True   True     True    True         True  ...
# 15457138                  False   True    False    True        False  ...
# 17555101                   True   True    False    True         True  ...
# 28234588                   True   True     True    True         True  ...
# ...                         ...    ...      ...     ...          ...  ...
# 13749393                  False   True    False   False        False  ...
# 27457076                  False   True    False   False        False  ...
# 25771345                   True   True     True    True         True  ...
# 19995526                  False  False    False   False        False  ...
# 24589287                   True   True     True    True         True  ...
#
#           amenities  square_feet security_deposit  cleaning_fee  \
# id
# 25761038      False          NaN              0.0          60.0
# 18440734      False          NaN            300.0          55.0
# 15457138      False          NaN            350.0           0.0
# 17555101      False          NaN              NaN           NaN
# 28234588      False          NaN              0.0           5.0
# ...             ...          ...              ...           ...
# 13749393      False          NaN            500.0          30.0
# 27457076      False          NaN              NaN           NaN
# 25771345      False          NaN              NaN           NaN
# 19995526      False          NaN              0.0          17.0
# 24589287      False          NaN            100.0          20.0
#
#          guests_included  extra_people minimum_nights  \
# id
# 25761038               2          15.0              2
# 18440734               1           0.0              2
# 15457138               1           0.0              2
# 17555101               1           0.0              2
# 28234588               1          10.0              2
# ...                  ...           ...            ...
# 13749393               1          15.0              4
# 27457076               1           0.0              4
# 25771345               1           0.0              1
# 19995526               1           0.0              2
# 24589287               1           0.0              3
#
#                   cancellation_policy require_guest_profile_picture  \
# id
# 25761038  strict_14_with_grace_period                         False
# 18440734  strict_14_with_grace_period                         False
# 15457138  strict_14_with_grace_period                         False
# 17555101  strict_14_with_grace_period                         False
# 28234588                     flexible                         False
# ...                               ...                           ...
# 13749393                     moderate                         False
# 27457076  strict_14_with_grace_period                         False
# 25771345                     flexible                         False
# 19995526  strict_14_with_grace_period                         False
# 24589287                     flexible                         False
#
#           require_guest_phone_verification
# id
# 25761038                             False
# 18440734                             False
# 15457138                             False
# 17555101                             False
# 28234588                             False
# ...                                    ...
# 13749393                             False
# 27457076                             False
# 25771345                             False
# 19995526                             False
# 24589287                             False
#
# [29016 rows x 41 columns]
