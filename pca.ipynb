# %% [markdown]
# # Оценка применения PCA

# %%
import pandas as pd
import numpy as np
from pca import pca

# %%
X_train_transf = np.load('X_train_transf.npy')
y_train = np.load('y_train.npy')

# %%
model = pca()
results = model.fit_transform(X_train_transf)
# Out:
# [pca] >Column labels are auto-completed.
# [pca] >Row labels are auto-completed.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [118] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [2] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [118] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]

# %%
model.plot();

# %%
model.results['explained_var']
# Out:
# array([0.64161609, 0.96884994, 0.98258424, 0.98550842, 0.98713636,
#        0.98815722, 0.98915837, 0.99004945, 0.99093756, 0.99177335,
#        0.99255573, 0.99323884, 0.99382395, 0.99436691, 0.99489037,
#        0.995363  , 0.99576497, 0.99613513, 0.99645624, 0.99674939,
#        0.9970215 , 0.99725842, 0.99747712, 0.99769076, 0.99789317,
#        0.99806581, 0.99823512, 0.99839443, 0.9985402 , 0.99867788,
#        0.99879844, 0.99891146, 0.99901365, 0.99910885, 0.99919862,
#        0.99928499, 0.99936448, 0.99943772, 0.99950744, 0.99957336,
#        0.99962799, 0.99967957, 0.99971488, 0.99974571, 0.99977222,
#        0.99979748, 0.99981445, 0.999829  , 0.99984137, 0.99985268,
#        0.99986344, 0.99987347, 0.99988273, 0.99989141, 0.99989966,
#        0.9999077 , 0.99991544, 0.99992231, 0.99992913, 0.99993534,
#        0.99994118, 0.99994635, 0.99995044, 0.99995439, 0.99995809,
#        0.99996137, 0.99996456, 0.99996747, 0.99997022, 0.99997255,
# ...

# %%
model.biplot(cmap=False, label=False, legend=False);
# Out:
# [pca] >Plot PC1 vs PC2 with loadings.

# %%
model.results['topfeat']
# Out:
#       PC feature   loading  type
# 0    PC1       5  0.987243  best
# 1    PC2       9 -0.999854  best
# 2    PC1       1 -0.005926  weak
# 3    PC2       2  0.001533  weak
# 4    PC1       3 -0.002704  weak
# ..   ...     ...       ...   ...
# 113  PC1     114 -0.002499  weak
# 114  PC2     115  0.000481  weak
# 115  PC1     116 -0.000523  weak
# 116  PC1     117  0.002427  weak
# 117  PC1     118 -0.000293  weak
#
# [118 rows x 4 columns]
